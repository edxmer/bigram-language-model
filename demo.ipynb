# %%
from bgn import BigramNetwork

# %%
network = BigramNetwork("data/cities_normalized.txt", 100)
# Out:
# /Users/edi/dev/ai/bigram-language-model/bgn.py:36: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.W = torch.tensor(torch.randn((self.n, self.n), dtype=torch.float32), requires_grad=True) # nxn

# %%
k = 120
for i in range(k):
    l = network.train()
    if (i<5 or k-5 <= i):
        print(f'{i:3}', l)
# Out:
#   0 tensor(3.6950, grad_fn=<NegBackward0>)
#   1 tensor(3.2415, grad_fn=<NegBackward0>)
#   2 tensor(3.0439, grad_fn=<NegBackward0>)
#   3 tensor(2.9277, grad_fn=<NegBackward0>)
#   4 tensor(2.8567, grad_fn=<NegBackward0>)
# 115 tensor(2.6097, grad_fn=<NegBackward0>)
# 116 tensor(2.6101, grad_fn=<NegBackward0>)
# 117 tensor(2.6096, grad_fn=<NegBackward0>)
# 118 tensor(2.6100, grad_fn=<NegBackward0>)
# 119 tensor(2.6095, grad_fn=<NegBackward0>)

# %%
# Predict a city name
for i in range(20):
    letters:list[str] = ['<b>']
    while True:
        sampled = network.sample(network.stoi[letters[-1]])
        letters.append(network.itos[int(sampled)])
        if (letters[-1] == '<b>'):
            break

    print(''.join(letters))
# Out:
# <b>dider<b>
# <b>barncar<b>
# <b>urarsa<b>
# <b>abezichele<b>
# <b>izandllangan<b>
# <b>cin<b>
# <b>nchunanur<b>
# <b>t<b>
# <b>swe<b>
# <b>goy<b>
# <b>dirir<b>
# <b>angumisvi<b>
# <b>brang<b>
# <b>tubo<b>
# <b>to<b>
# <b>mudoba<b>
# <b>michon<b>
# <b>qumber<b>
# <b>ton<b>
# <b>shichatainichelusti<b>
