# %%
from bgn import BigramNetwork

# %%
network = BigramNetwork("data/cities_normalized.txt", 100)

# %%
k = 120
for i in range(k):
    l = network.train()
    if (i<5 or k-5 <= i):
        print(f'{i:3}', l)
# Out:
#   0 tensor(3.5618, grad_fn=<NegBackward0>)
#   1 tensor(3.2033, grad_fn=<NegBackward0>)
#   2 tensor(3.0139, grad_fn=<NegBackward0>)
#   3 tensor(2.9031, grad_fn=<NegBackward0>)
#   4 tensor(2.8336, grad_fn=<NegBackward0>)
# 115 tensor(2.6095, grad_fn=<NegBackward0>)
# 116 tensor(2.6099, grad_fn=<NegBackward0>)
# 117 tensor(2.6094, grad_fn=<NegBackward0>)
# 118 tensor(2.6098, grad_fn=<NegBackward0>)
# 119 tensor(2.6093, grad_fn=<NegBackward0>)

# %%
# Predict a city name
for i in range(20):
    letters:list[str] = ['<b>']
    while True:
        sampled = network.sample(network.stoi[letters[-1]])
        letters.append(network.itos[int(sampled)])
        if (letters[-1] == '<b>'):
            break

    print(''.join(letters))
# Out:
# <b>siraronal<b>
# <b>tsiahivan<b>
# <b><b>
# <b>kee<b>
# <b>kashacrgleri<b>
# <b>a<b>
# <b>ajibawaminjit<b>
# <b>pech<b>
# <b>chie<b>
# <b>chanftszaticharnede<b>
# <b>ui<b>
# <b>roszhyomen<b>
# <b>diz<b>
# <b>tlindingoupito<b>
# <b>lldin<b>
# <b>abwa<b>
# <b>i<b>
# <b>hixxi<b>
# <b>nireri<b>
# <b>t<b>
